# %%
# Out:
# (217, 2) (146, 2)
# The classification rate is 0.85 (124 of 146 were correct).
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %%
plt.imshow(np.random.rand(10**4,10**4))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
